# %%
# %matplotlib inline
import pandas as pd, seaborn as sns, numpy as np, os, matplotlib.pyplot as plt
from tqdm import tqdm
import missingno as msno
from helper_funcs import *
import json, os
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, precision_score, recall_score, balanced_accuracy_score
from sklearn.externals import joblib
from imblearn.ensemble import BalancedRandomForestClassifier # !!!!!! balanced!
from IPython.display import display, Markdown

def md(txt): display(Markdown(txt))

if not 'df' in globals(): 
    df = pd.read_parquet('data/involved_hebrew.parquet')
    df, val_map, imputed, cols = remove_hebrew_and_impute(df)
    X,Y, x_cols = get_XY(df, cols)

X.shape, Y.shape
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 289/289 [00:03<00:00, 79.12it/s]
# ((1623850, 131), (1623850,))

# %% [markdown]
# # Split the data and train model

# %%
if not 'X_train' in globals(): 
    X_train, X_test, y_train, y_test = train_test_split(X, Y, random_state=42, test_size=0.25)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (1217887, 131) (405963, 131) (1217887,) (405963,)

# %%
if not 'brf' in globals(): 
    brf = BalancedRandomForestClassifier(n_estimators=30, random_state=0)
    brf.fit(X_train, y_train)
print('trained!')
# Out:
# trained!

# %% [markdown]
# # Evaluate model

# %%
if not 'y_pred' in globals(): 
    y_pred = brf.predict(X_test)

md('### f1 score = %.3f'%(f1_score(y_test, y_pred, average='weighted')))
md('### precision = %.3f'%(precision_score(y_test, y_pred, average='weighted')))
md('### recall = %.3f'%(recall_score(y_test, y_pred, average='weighted')))
md('### accuracy(balanced) = %.3f'%(balanced_accuracy_score(y_test, y_pred)))
# Out:
# ### f1 score = 0.857
# ### precision = 0.982
# ### recall = 0.769
# ### accuracy(balanced) = 0.782

# %% [markdown]
# -----
# # Save the model

# %%
model_fname = 'models/2018_11_20_injury_risk_balanced_RF_classifier_02.joblib'
if not os.path.isdir('models'): 
    os.mkdir('models')
if not os.path.isfile(model_fname):
    joblib.dump(brf, model_fname)

# %% [markdown]
# ---
# # Train model on all the data

# %%
brf.fit(X, Y)
# Out:
# BalancedRandomForestClassifier(bootstrap=True, class_weight=None,
#                 criterion='gini', max_depth=None, max_features='auto',
#                 max_leaf_nodes=None, min_impurity_decrease=0.0,
#                 min_samples_leaf=2, min_samples_split=2,
#                 min_weight_fraction_leaf=0.0, n_estimators=30, n_jobs=1,
#                 oob_score=False, random_state=0, replacement=False,
#                 sampling_strategy='auto', verbose=0, warm_start=False)

# %% [markdown]
# # save the full model

# %%
model_fname = 'models/2018_11_20_injury_risk_balanced_RF_classifier_full_03.joblib'
if not os.path.isdir('models'): 
    os.mkdir('models')
if not os.path.isfile(model_fname):
    joblib.dump(brf, model_fname)

# %% [markdown]
# ---
# # Evaluate naive feature importance

# %%
importance = pd.DataFrame(list(zip(x_cols, brf.feature_importances_)), 
                          columns=['feature', 'importance']).sort_values('importance', ascending=False)
importance[0:30].style.bar()
# Out:
# <style  type="text/css" >
#     #T_8af5a118_ed3f_11e8_87ae_40a3cc98b830row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#         }    #T_8af5a118_ed3f_11e8_87ae_40a3cc98b830row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 98.8%, transparent 0%);
#         }    #T_8af5a118_ed3f_11e8_87ae_40a3cc98b830row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 77.2%, transparent 0%);
#         }    #T_8af5a118_ed3f_11e8_87ae_40a3cc98b830row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 59.7%, transparent 0%);
#         }    #T_8af5a118_ed3f_11e8_87ae_40a3cc98b830row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 55.1%, transparent 0%);
#         }    #T_8af5a118_ed3f_11e8_87ae_40a3cc98b830row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 48.1%, transparent 0%);
#         }    #T_8af5a118_ed3f_11e8_87ae_40a3cc98b830row6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 37.0%, transparent 0%);
#         }    #T_8af5a118_ed3f_11e8_87ae_40a3cc98b830row7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 26.7%, transparent 0%);
#         }    #T_8af5a118_ed3f_11e8_87ae_40a3cc98b830row8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 26.1%, transparent 0%);
#         }    #T_8af5a118_ed3f_11e8_87ae_40a3cc98b830row9_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.1%, transparent 0%);
#         }    #T_8af5a118_ed3f_11e8_87ae_40a3cc98b830row10_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 18.5%, transparent 0%);
#         }    #T_8af5a118_ed3f_11e8_87ae_40a3cc98b830row11_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 11.3%, transparent 0%);
#         }    #T_8af5a118_ed3f_11e8_87ae_40a3cc98b830row12_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 11.1%, transparent 0%);
#         }    #T_8af5a118_ed3f_11e8_87ae_40a3cc98b830row13_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 10.0%, transparent 0%);
#         }    #T_8af5a118_ed3f_11e8_87ae_40a3cc98b830row14_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 9.4%, transparent 0%);
#         }    #T_8af5a118_ed3f_11e8_87ae_40a3cc98b830row15_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 8.9%, transparent 0%);
#         }    #T_8af5a118_ed3f_11e8_87ae_40a3cc98b830row16_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 7.8%, transparent 0%);
#         }    #T_8af5a118_ed3f_11e8_87ae_40a3cc98b830row17_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 6.2%, transparent 0%);
#         }    #T_8af5a118_ed3f_11e8_87ae_40a3cc98b830row18_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 5.2%, transparent 0%);
#         }    #T_8af5a118_ed3f_11e8_87ae_40a3cc98b830row19_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.7%, transparent 0%);
#         }    #T_8af5a118_ed3f_11e8_87ae_40a3cc98b830row20_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.4%, transparent 0%);
#         }    #T_8af5a118_ed3f_11e8_87ae_40a3cc98b830row21_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.3%, transparent 0%);
#         }    #T_8af5a118_ed3f_11e8_87ae_40a3cc98b830row22_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.2%, transparent 0%);
#         }    #T_8af5a118_ed3f_11e8_87ae_40a3cc98b830row23_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.6%, transparent 0%);
#         }    #T_8af5a118_ed3f_11e8_87ae_40a3cc98b830row24_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.5%, transparent 0%);
#         }    #T_8af5a118_ed3f_11e8_87ae_40a3cc98b830row25_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.4%, transparent 0%);
#         }    #T_8af5a118_ed3f_11e8_87ae_40a3cc98b830row26_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.7%, transparent 0%);
#         }    #T_8af5a118_ed3f_11e8_87ae_40a3cc98b830row27_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.6%, transparent 0%);
#         }    #T_8af5a118_ed3f_11e8_87ae_40a3cc98b830row28_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.3%, transparent 0%);
#         }    #T_8af5a118_ed3f_11e8_87ae_40a3cc98b830row29_col1 {
#             width:  10em;
#              height:  80%;
#         }</style>
# <table id="T_8af5a118_ed3f_11e8_87ae_40a3cc98b830" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >feature</th>
#         <th class="col_heading level0 col1" >importance</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_8af5a118_ed3f_11e8_87ae_40a3cc98b830level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_8af5a118_ed3f_11e8_87ae_40a3cc98b830row0_col0" class="data row0 col0" >license_acquiring_date</td>
#         <td id="T_8af5a118_ed3f_11e8_87ae_40a3cc98b830row0_col1" class="data row0 col1" >0.082491</td>
#     </tr>    <tr>
#         <th id="T_8af5a118_ed3f_11e8_87ae_40a3cc98b830level0_row1" class="row_heading level0 row1" >23</th>
#         <td id="T_8af5a118_ed3f_11e8_87ae_40a3cc98b830row1_col0" class="data row1 col0" >vehicle_type=1.0</td>
#         <td id="T_8af5a118_ed3f_11e8_87ae_40a3cc98b830row1_col1" class="data row1 col1" >0.0815605</td>
#     </tr>    <tr>
#         <th id="T_8af5a118_ed3f_11e8_87ae_40a3cc98b830level0_row2" class="row_heading level0 row2" >20</th>
#         <td id="T_8af5a118_ed3f_11e8_87ae_40a3cc98b830row2_col0" class="data row2 col0" >age_group=99</td>
#         <td id="T_8af5a118_ed3f_11e8_87ae_40a3cc98b830row2_col1" class="data row2 col1" >0.0654334</td>
#     </tr>    <tr>
#         <th id="T_8af5a118_ed3f_11e8_87ae_40a3cc98b830level0_row3" class="row_heading level0 row3" >1</th>
#         <td id="T_8af5a118_ed3f_11e8_87ae_40a3cc98b830row3_col0" class="data row3 col0" >accident_year</td>
#         <td id="T_8af5a118_ed3f_11e8_87ae_40a3cc98b830row3_col1" class="data row3 col1" >0.0522524</td>
#     </tr>    <tr>
#         <th id="T_8af5a118_ed3f_11e8_87ae_40a3cc98b830level0_row4" class="row_heading level0 row4" >2</th>
#         <td id="T_8af5a118_ed3f_11e8_87ae_40a3cc98b830row4_col0" class="data row4 col0" >accident_month</td>
#         <td id="T_8af5a118_ed3f_11e8_87ae_40a3cc98b830row4_col1" class="data row4 col1" >0.0488292</td>
#     </tr>    <tr>
#         <th id="T_8af5a118_ed3f_11e8_87ae_40a3cc98b830level0_row5" class="row_heading level0 row5" >69</th>
#         <td id="T_8af5a118_ed3f_11e8_87ae_40a3cc98b830row5_c

# %% [markdown]
# # evaluate features using 'permutation_importances'

# %%
imp_fname = 'data/2018_11_20_injury_risk_balanced_RF_classifier_full_03_permutations_importnace.csv'
if not os.path.isfile(imp_fname):
    xx = pd.DataFrame(X, columns=x_cols)
    permu_imp = permutation_importances(brf, xx, Y)
    imp = pd.DataFrame(list(zip(x_cols, permu_imp)), columns=['feature', 'permutation_importance'])
    imp.to_csv(imp_fname, index=False)
else:
    imp = pd.read_csv(imp_fname)
imp.sort_values('permutation_importance', ascending=False)[0:30].style.bar()
# Out:
# <style  type="text/css" >
#     #T_93403b4a_ed3f_11e8_861e_40a3cc98b830row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#         }    #T_93403b4a_ed3f_11e8_861e_40a3cc98b830row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 53.7%, transparent 0%);
#         }    #T_93403b4a_ed3f_11e8_861e_40a3cc98b830row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 49.7%, transparent 0%);
#         }    #T_93403b4a_ed3f_11e8_861e_40a3cc98b830row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 35.6%, transparent 0%);
#         }    #T_93403b4a_ed3f_11e8_861e_40a3cc98b830row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 29.7%, transparent 0%);
#         }    #T_93403b4a_ed3f_11e8_861e_40a3cc98b830row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 27.7%, transparent 0%);
#         }    #T_93403b4a_ed3f_11e8_861e_40a3cc98b830row6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.2%, transparent 0%);
#         }    #T_93403b4a_ed3f_11e8_861e_40a3cc98b830row7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 18.6%, transparent 0%);
#         }    #T_93403b4a_ed3f_11e8_861e_40a3cc98b830row8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 17.3%, transparent 0%);
#         }    #T_93403b4a_ed3f_11e8_861e_40a3cc98b830row9_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 16.7%, transparent 0%);
#         }    #T_93403b4a_ed3f_11e8_861e_40a3cc98b830row10_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 12.8%, transparent 0%);
#         }    #T_93403b4a_ed3f_11e8_861e_40a3cc98b830row11_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 12.2%, transparent 0%);
#         }    #T_93403b4a_ed3f_11e8_861e_40a3cc98b830row12_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 10.0%, transparent 0%);
#         }    #T_93403b4a_ed3f_11e8_861e_40a3cc98b830row13_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 8.9%, transparent 0%);
#         }    #T_93403b4a_ed3f_11e8_861e_40a3cc98b830row14_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 8.6%, transparent 0%);
#         }    #T_93403b4a_ed3f_11e8_861e_40a3cc98b830row15_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 8.3%, transparent 0%);
#         }    #T_93403b4a_ed3f_11e8_861e_40a3cc98b830row16_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 7.4%, transparent 0%);
#         }    #T_93403b4a_ed3f_11e8_861e_40a3cc98b830row17_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 5.7%, transparent 0%);
#         }    #T_93403b4a_ed3f_11e8_861e_40a3cc98b830row18_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.6%, transparent 0%);
#         }    #T_93403b4a_ed3f_11e8_861e_40a3cc98b830row19_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.6%, transparent 0%);
#         }    #T_93403b4a_ed3f_11e8_861e_40a3cc98b830row20_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.5%, transparent 0%);
#         }    #T_93403b4a_ed3f_11e8_861e_40a3cc98b830row21_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.5%, transparent 0%);
#         }    #T_93403b4a_ed3f_11e8_861e_40a3cc98b830row22_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.0%, transparent 0%);
#         }    #T_93403b4a_ed3f_11e8_861e_40a3cc98b830row23_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.8%, transparent 0%);
#         }    #T_93403b4a_ed3f_11e8_861e_40a3cc98b830row24_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.7%, transparent 0%);
#         }    #T_93403b4a_ed3f_11e8_861e_40a3cc98b830row25_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.7%, transparent 0%);
#         }    #T_93403b4a_ed3f_11e8_861e_40a3cc98b830row26_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.6%, transparent 0%);
#         }    #T_93403b4a_ed3f_11e8_861e_40a3cc98b830row27_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.4%, transparent 0%);
#         }    #T_93403b4a_ed3f_11e8_861e_40a3cc98b830row28_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.3%, transparent 0%);
#         }    #T_93403b4a_ed3f_11e8_861e_40a3cc98b830row29_col1 {
#             width:  10em;
#              height:  80%;
#         }</style>
# <table id="T_93403b4a_ed3f_11e8_861e_40a3cc98b830" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >feature</th>
#         <th class="col_heading level0 col1" >permutation_importance</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_93403b4a_ed3f_11e8_861e_40a3cc98b830level0_row0" class="row_heading level0 row0" >23</th>
#         <td id="T_93403b4a_ed3f_11e8_861e_40a3cc98b830row0_col0" class="data row0 col0" >vehicle_type=1.0</td>
#         <td id="T_93403b4a_ed3f_11e8_861e_40a3cc98b830row0_col1" class="data row0 col1" >0.0768382</td>
#     </tr>    <tr>
#         <th id="T_93403b4a_ed3f_11e8_861e_40a3cc98b830level0_row1" class="row_heading level0 row1" >20</th>
#         <td id="T_93403b4a_ed3f_11e8_861e_40a3cc98b830row1_col0" class="data row1 col0" >age_group=99</td>
#         <td id="T_93403b4a_ed3f_11e8_861e_40a3cc98b830row1_col1" class="data row1 col1" >0.0426977</td>
#     </tr>    <tr>
#         <th id="T_93403b4a_ed3f_11e8_861e_40a3cc98b830level0_row2" class="row_heading level0 row2" >0</th>
#         <td id="T_93403b4a_ed3f_11e8_861e_40a3cc98b830row2_col0" class="data row2 col0" >license_acquiring_date</td>
#         <td id="T_93403b4a_ed3f_11e8_861e_40a3cc98b830row2_col1" class="data row2 col1" >0.0397759</td>
#     </tr>    <tr>
#         <th id="T_93403b4a_ed3f_11e8_861e_40a3cc98b830level0_row3" class="row_heading level0 row3" >121</th>
#         <td id="T_93403b4a_ed3f_11e8_861e_40a3cc98b830row3_col0" class="data row3 col0" >car_id=1.0</td>
#         <td id="T_93403b4a_ed3f_11e8_861e_40a3cc98b830row3_col1" class="data row3 col1" >0.0293862</td>
#     </tr>    <tr>
#         <th id="T_93403b4a_ed3f_11e8_861e_40a3cc98b830level0_row4" class="row_heading level0 row4" >40</th>
#         <td id="T_93403b4a_ed3f_11e8_861e_40a3cc98b830row4_col0" class="data row4 col0" >safety_measures=5.0</td>
#         <td id="T_93403b4a_ed3f_11e8_861e_40a3cc98b830row4_col1" class="data row4 col1" >0.0250811</td>
#     </tr>    <tr>
#         <th id="T_93403b4a_ed3f_11e8_861e_40a3cc98b830level0_row5" class="row_heading level0 row5" >1</th>
#         <td id="T_93403b4a_ed3f_11e8_861e_40

# %% [markdown]
# # combine importance to the 'parent' feature

# %%
splt = pd.concat([imp, pd.DataFrame(imp['feature'].str.split('=').tolist(), 
                             columns=['main_feature', 'num'])], 
          axis=1)
gb = splt.groupby('main_feature').sum()
gb = gb.sort_values('permutation_importance', ascending=False)
gb = gb.reset_index()
gb.style.bar()
# Out:
# <style  type="text/css" >
#     #T_96abbb74_ed3f_11e8_a162_40a3cc98b830row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#         }    #T_96abbb74_ed3f_11e8_a162_40a3cc98b830row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 67.8%, transparent 0%);
#         }    #T_96abbb74_ed3f_11e8_a162_40a3cc98b830row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 38.3%, transparent 0%);
#         }    #T_96abbb74_ed3f_11e8_a162_40a3cc98b830row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 29.8%, transparent 0%);
#         }    #T_96abbb74_ed3f_11e8_a162_40a3cc98b830row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 28.6%, transparent 0%);
#         }    #T_96abbb74_ed3f_11e8_a162_40a3cc98b830row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 22.8%, transparent 0%);
#         }    #T_96abbb74_ed3f_11e8_a162_40a3cc98b830row6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 21.0%, transparent 0%);
#         }    #T_96abbb74_ed3f_11e8_a162_40a3cc98b830row7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 13.9%, transparent 0%);
#         }    #T_96abbb74_ed3f_11e8_a162_40a3cc98b830row8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 11.2%, transparent 0%);
#         }    #T_96abbb74_ed3f_11e8_a162_40a3cc98b830row9_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 9.9%, transparent 0%);
#         }    #T_96abbb74_ed3f_11e8_a162_40a3cc98b830row10_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 9.3%, transparent 0%);
#         }    #T_96abbb74_ed3f_11e8_a162_40a3cc98b830row11_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 6.5%, transparent 0%);
#         }    #T_96abbb74_ed3f_11e8_a162_40a3cc98b830row12_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.1%, transparent 0%);
#         }    #T_96abbb74_ed3f_11e8_a162_40a3cc98b830row13_col1 {
#             width:  10em;
#              height:  80%;
#         }</style>
# <table id="T_96abbb74_ed3f_11e8_a162_40a3cc98b830" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >main_feature</th>
#         <th class="col_heading level0 col1" >permutation_importance</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_96abbb74_ed3f_11e8_a162_40a3cc98b830level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_96abbb74_ed3f_11e8_a162_40a3cc98b830row0_col0" class="data row0 col0" >vehicle_type</td>
#         <td id="T_96abbb74_ed3f_11e8_a162_40a3cc98b830row0_col1" class="data row0 col1" >0.10648</td>
#     </tr>    <tr>
#         <th id="T_96abbb74_ed3f_11e8_a162_40a3cc98b830level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_96abbb74_ed3f_11e8_a162_40a3cc98b830row1_col0" class="data row1 col0" >age_group</td>
#         <td id="T_96abbb74_ed3f_11e8_a162_40a3cc98b830row1_col1" class="data row1 col1" >0.0764009</td>
#     </tr>    <tr>
#         <th id="T_96abbb74_ed3f_11e8_a162_40a3cc98b830level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_96abbb74_ed3f_11e8_a162_40a3cc98b830row2_col0" class="data row2 col0" >car_id</td>
#         <td id="T_96abbb74_ed3f_11e8_a162_40a3cc98b830row2_col1" class="data row2 col1" >0.0488509</td>
#     </tr>    <tr>
#         <th id="T_96abbb74_ed3f_11e8_a162_40a3cc98b830level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_96abbb74_ed3f_11e8_a162_40a3cc98b830row3_col0" class="data row3 col0" >safety_measures</td>
#         <td id="T_96abbb74_ed3f_11e8_a162_40a3cc98b830row3_col1" class="data row3 col1" >0.0409203</td>
#     </tr>    <tr>
#         <th id="T_96abbb74_ed3f_11e8_a162_40a3cc98b830level0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_96abbb74_ed3f_11e8_a162_40a3cc98b830row4_col0" class="data row4 col0" >license_acquiring_date</td>
#         <td id="T_96abbb74_ed3f_11e8_a162_40a3cc98b830row4_col1" class="data row4 col1" >0.0397759</td>
#     </tr>    <tr>
#         <th id="T_96abbb74_ed3f_11e8_a162_40a3cc98b830level0_row5" class="row_heading level0 row5" >5</th>
#         <td id="T_96abbb74_ed3f_11e8_a162_40a3cc98b830row5_col0" class="data row5 col0" >home_district</td>
#         <td id="T_96abbb74_ed3f_11e8_a162_40a3cc98b830row5_col1" class="data row5 col1" >0.0343374</td>
#     </tr>    <tr>
#         <th id="T_96abbb74_ed3f_11e8_a162_40a3cc98b830level0_row6" class="row_heading level0 row6" >6</th>
#         <td id="T_96abbb74_ed3f_11e8_a162_40a3cc98b830row6_col0" class="data row6 col0" >involve_id</td>
#         <td id="T_96abbb74_ed3f_11e8_a162_40a3cc98b830row6_col1" class="data row6 col1" >0.0327232</td>
#     </tr>    <tr>
#         <th id="T_96abbb74_ed3f_11e8_a162_40a3cc98b830level0_row7" class="row_heading level0 row7" >7</th>
#         <td id="T_96abbb74_ed3f_11e8_a162_40a3cc98b830row7_col0" class="data row7 col0" >home_region</td>
#         <td id="T_96abbb74_ed3f_11e8_a162_40a3cc98b830row7_col1" class="data row7 col1" >0.0260697</td>
#     </tr>    <tr>
#         <th id="T_96abbb74_ed3f_11e8_a162_40a3cc98b830level0_row8" class="row_heading level0 row8" >8</th>
#         <td id="T_96abbb74_ed3f_11e8_a162_40a3cc98b830row8_col0" class="data row8 col0" >accident_year</td>
#         <td id="T_96abbb74_ed3f_11e8_a162_40a3cc98b830row8_col1" class="data row8 col1" >0.0235801</td>
#     </tr>    <tr>
#         <th id="T_96abbb74_ed3f_11e8_a162_40a3cc98b830level0_row9" class="row_heading level0 row9" >9</th>
#         <td id="T_96abbb74_ed3f_11e8_a162_40a3cc98b830row9_col0" class="data row9 col0" >sex</td>
#         <td id="T_96abbb74_ed3f_11e8_a162_40a3cc98b830row9_col1" class="data row9 col1" >0.022308</td>
#     </tr>    <tr>
#         <th id="T_96abbb74_ed3f_11e8_a162_40a3cc98b830level0_row10" class="row_heading level0 row10" >10</th>
#         <td id="T_96abbb74_ed3f_11e8_a162_40a3cc98b830row10_col0" class="data row10 col0" >home_residence_type</td>
#         <td id="T_96abbb74_ed3f_11e8_a162_40a3cc98b830row10_col1" class="data row10 col1" >0.0217922</td>
#     </tr>    <tr>
#         <th id="T_96abbb74_ed3f_11e8_a162_40a3cc98b830level0_row11" class="row_heading level0 row11" >11</th>
#         <td id="T_96abbb74_ed3f_11e8_a162_40a3cc98b830row11_col0" class="data row11 col0" >population_type</td>
#         <td id="T_96abbb74_ed3f_11e8_a162_40a3cc98b830row11_col1" class="data row11 col1" >0.0191469</td>
#     </tr>    <tr>
#         <th id="T_96abbb74_ed3f_11e8_a162_40a3cc98b830level0_row12" class="row_heading level0 row12" >12</th>
#         <td id="T_96abbb74_ed3f_11e8_a162_40a3cc98b830row12_col0" class="data row12 col0" >accident_month</td>
#         <td id="T_96abbb74_ed3f_11e8_a162_40a3cc98b830row12_col1" class="data row12 col1" >0.0159267</td>
#     </tr>    <tr>
#         <th id="T_96abbb74_ed3f_11e8_a162_40a3cc98b830level0_row13" class="row_heading level0 row13" >13</th>
#         <td id="T_96abbb74_ed3f_11e8_a162_40a3cc98b830row13_col0" class="data row13 col0" >home_natural_area</td>
#         <td id="T_96abbb74_ed3f_11e8_a162_40a3cc98b830row13_col1" class="data row13 col1" >0.013073</td>
#     </tr></tbody>
# </table>

# %%
splt.head()
# Out:
#                   feature  permutation_importance            main_feature  \
# 0  license_acquiring_date                0.039776  license_acquiring_date
# 1           accident_year                0.023580           accident_year
# 2          accident_month                0.015927          accident_month
# 3             age_group=1                0.001031               age_group
# 4             age_group=2                0.000631               age_group
#
#     num
# 0  None
# 1  None
# 2  None
# 3     1
# 4     2

# %%
translation = [f + '=' + val_map[f].get(str(v), v) if f in val_map.keys() else f +'=' + str(v) for f,v in splt[['main_feature', 'num']].values]
splt['translation'] = translation
splt = splt[['translation', 'permutation_importance']].sort_values('permutation_importance', ascending=False)
splt.style.bar()
# Out:
# <style  type="text/css" >
#     #T_e1917274_ed3f_11e8_9e73_40a3cc98b830row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#         }    #T_e1917274_ed3f_11e8_9e73_40a3cc98b830row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 55.5%, transparent 0%);
#         }    #T_e1917274_ed3f_11e8_9e73_40a3cc98b830row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 51.7%, transparent 0%);
#         }    #T_e1917274_ed3f_11e8_9e73_40a3cc98b830row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 38.2%, transparent 0%);
#         }    #T_e1917274_ed3f_11e8_9e73_40a3cc98b830row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 32.6%, transparent 0%);
#         }    #T_e1917274_ed3f_11e8_9e73_40a3cc98b830row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 30.6%, transparent 0%);
#         }    #T_e1917274_ed3f_11e8_9e73_40a3cc98b830row6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 23.4%, transparent 0%);
#         }    #T_e1917274_ed3f_11e8_9e73_40a3cc98b830row7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 21.9%, transparent 0%);
#         }    #T_e1917274_ed3f_11e8_9e73_40a3cc98b830row8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.7%, transparent 0%);
#         }    #T_e1917274_ed3f_11e8_9e73_40a3cc98b830row9_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.1%, transparent 0%);
#         }    #T_e1917274_ed3f_11e8_9e73_40a3cc98b830row10_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 16.3%, transparent 0%);
#         }    #T_e1917274_ed3f_11e8_9e73_40a3cc98b830row11_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 15.8%, transparent 0%);
#         }    #T_e1917274_ed3f_11e8_9e73_40a3cc98b830row12_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 13.6%, transparent 0%);
#         }    #T_e1917274_ed3f_11e8_9e73_40a3cc98b830row13_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 12.6%, transparent 0%);
#         }    #T_e1917274_ed3f_11e8_9e73_40a3cc98b830row14_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 12.3%, transparent 0%);
#         }    #T_e1917274_ed3f_11e8_9e73_40a3cc98b830row15_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 12.1%, transparent 0%);
#         }    #T_e1917274_ed3f_11e8_9e73_40a3cc98b830row16_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 11.1%, transparent 0%);
#         }    #T_e1917274_ed3f_11e8_9e73_40a3cc98b830row17_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 9.6%, transparent 0%);
#         }    #T_e1917274_ed3f_11e8_9e73_40a3cc98b830row18_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 7.5%, transparent 0%);
#         }    #T_e1917274_ed3f_11e8_9e73_40a3cc98b830row19_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 5.6%, transparent 0%);
#         }    #T_e1917274_ed3f_11e8_9e73_40a3cc98b830row20_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 5.5%, transparent 0%);
#         }    #T_e1917274_ed3f_11e8_9e73_40a3cc98b830row21_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 5.5%, transparent 0%);
#         }    #T_e1917274_ed3f_11e8_9e73_40a3cc98b830row22_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 5.0%, transparent 0%);
#         }    #T_e1917274_ed3f_11e8_9e73_40a3cc98b830row23_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 4.9%, transparent 0%);
#         }    #T_e1917274_ed3f_11e8_9e73_40a3cc98b830row24_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 4.8%, transparent 0%);
#         }    #T_e1917274_ed3f_11e8_9e73_40a3cc98b830row25_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 4.7%, transparent 0%);
#         }    #T_e1917274_ed3f_11e8_9e73_40a3cc98b830row26_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 4.6%, transparent 0%);
#         }    #T_e1917274_ed3f_11e8_9e73_40a3cc98b830row27_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 4.4%, transparent 0%);
#         }    #T_e1917274_ed3f_11e8_9e73_40a3cc98b830row28_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 4.4%, transparent 0%);
#         }    #T_e1917274_ed3f_11e8_9e73_40a3cc98b830row29_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 4.1%, transparent 0%);
#         }    #T_e1917274_ed3f_11e8_9e73_40a3cc98b830row30_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.9%, transparent 0%);
#         }    #T_e1917274_ed3f_11e8_9e73_40a3cc98b830row31_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.9%, transparent 0%);
#         }    #T_e1917274_ed3f_11e8_9e73_40a3cc98b830row32_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.3%, transparent 0%);
#         }    #T_e1917274_ed3f_11e8_9e73_40a3cc98b830row33_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.1%, transparent 0%);
#         }    #T_e1917274_ed3f_11e8_9e73_40a3cc98b830row34_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.1%, transparent 0%);
#         }    #T_e1917274_ed3f_11e8_9e73_40a3cc98b830row35_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.1%, transparent 0%);
#         }    #T_e1917274_ed3f_11e8_9e73_40a3cc98b830row36_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.0%, transparent 0%);
#         }    #T_e1917274_ed3f_11e8_9e73_40a3cc98b830row37_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.8%, transparent 0%);
#         }    #T_e1917274_ed3f_11e8_9e73_40a3cc98b830row38_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.7%, transparent 0%);
#         }    #T_e1917274_ed3f_11e8_9e73_40a3cc98b830row39_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.6%, transparent 0%);
#         }    #T_e1917274_ed3f_11e8_9e73_40a3cc98b830row40_col1 {
#             width:  10em;
#              height:  80%;
#             backg
