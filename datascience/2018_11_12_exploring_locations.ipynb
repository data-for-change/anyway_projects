# %%
# %matplotlib inline
import pandas as pd, seaborn as sns, numpy as np, os, matplotlib.pyplot as plt, json
from tqdm import tqdm

# %%
cams = pd.read_excel('data/cameras_policing_nov_2018.xlsx')
{c:'' for c in cams.columns}
# Out:
# {'מספר סידורי': '',
#  'מיקום המצלמה': '',
#  'תחום': '',
#  'סוג המצלמה': '',
#  'זרוע ראשית': '',
#  'זרוע משנית': '',
#  'ק"מ בו מותקנת העמדה': '',
#  'כיוון': '',
#  'Latitude': '',
#  'Longitude': '',
#  'תאריך הקמה': ''}

# %%
names = {'מספר סידורי': 'id',
 'מיקום המצלמה': 'location',
 'תחום': 'area',
 'סוג המצלמה': 'type',
 'זרוע ראשית': 'main_arm',
 'זרוע משנית': 'secondary_arm',
 'ק"מ בו מותקנת העמדה': 'km_station_location',
 'כיוון': 'direction',
 'Latitude': 'latitude',
 'Longitude': 'longitude',
 'תאריך הקמה': 'date'}

cams = cams.rename(columns=names)
cams
# Out:
#       id                                   location       area    type  \
# 0      1                                      אשדוד     עירוני   רמזור
# 1      2                                     אשקלון     עירוני   רמזור
# 2      3                                     אשקלון     עירוני   רמזור
# 3      4                                    באר שבע     עירוני   רמזור
# 4      5                                      בת ים     עירוני  מהירות
# 5      6                                      בת ים     עירוני   רמזור
# 6      7                                  הוד השרון     עירוני   רמזור
# 7      8                                       חדרה     עירוני   רמזור
# 8      9                                      חולון     עירוני   רמזור
# 9     10                                      חולון     עירוני   רמזור
# 10    11                                      חולון     עירוני   רמזור
# 11    12                                      חולון     עירוני   רמזור
# ...
